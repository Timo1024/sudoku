# %%
import numpy as np
import random
from copy import deepcopy
import time
import sys
import importlib

# %%
import sudoku
importlib.reload(sudoku)
# Out:
# <module 'sudoku' from 'e:\\programming\\sudoku\\src\\sudoku.py'>

# %%
import sudoku
importlib.reload(sudoku)

new_sudoku = sudoku.Sudoku()
new_sudoku.display(solved=True)
print(new_sudoku.count_solutions())
new_sudoku.removeValues(50)
new_sudoku.display(solved=False)
print(new_sudoku.count_solutions())
print(new_sudoku.countEmpty())

new_sudoku.displayAsPlot()
# Out:
# Initializing Sudoku...
# +-----------+-----------+
# |  2  6  4  |  3  1  5  |
# |  5  3  1  |  2  4  6  |
# +-----------+-----------+
# |  6  1  5  |  4  3  2  |
# |  3  4  2  |  6  5  1  |
# +-----------+-----------+
# |  1  2  3  |  5  6  4  |
# |  4  5  6  |  1  2  3  |
# +-----------+-----------+
# 1
# +-----------+-----------+
# |  2  6  _  |  _  _  5  |
# |  _  _  1  |  _  _  _  |
# +-----------+-----------+
# |  _  _  _  |  _  3  _  |
# |  _  4  _  |  _  _  _  |
# +-----------+-----------+
# |  1  2  _  |  _  6  _  |
# |  _  _  _  |  _  _  3  |
# +-----------+-----------+
# 1
# 26

# %%
print(new_sudoku.getIncreasingLines())
# Out:
# [[(0, 1), (0, 2), (1, 1), (1, 2), (1, 3), (2, 1), (2, 0), (1, 0)], [(0, 4), (0, 5), (1, 5)], [(1, 4), (2, 4), (3, 4), (3, 5), (4, 4), (2, 3)], [(2, 2), (3, 2), (4, 2), (3, 1)], [(3, 0), (4, 0), (4, 1), (5, 1), (5, 0)], [(4, 3), (5, 3), (5, 4)]]
